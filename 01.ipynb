# %%
import pandas as pd
import numpy as np

# %%
# stirng = object in pd

country=["India","Pakistan","USA","Nepal","Srilanka"]   # list


pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# int

runs=[13,23,45,100]

pd.Series(runs)
# Out:
# 0     13
# 1     23
# 2     45
# 3    100
# dtype: int64

# %%
# custom index

marks=[67,56,100,89]
subject=['math','eng','bl','math']

pd.Series(marks,index=subject)
# Out:
# math     67
# eng      56
# bl      100
# math     89
# dtype: int64

# %%
#setting a name

pd.Series(marks,index=subject,name='makrs of rakib')
# Out:
# math     67
# eng      56
# bl      100
# math     89
# Name: makrs of rakib, dtype: int64

# %%
marks=pd.Series(marks,index=subject,name='marks of rakib')
marks
# Out:
# math     67
# eng      56
# bl      100
# math     89
# Name: marks of rakib, dtype: int64

# %%
# series from dict

marks={

'math' :67,
'eng':57,
    'science':89,
    'arbi':100
}

marks_series =pd.Series(marks,name='rakib ar marks')
    
marks_series
# Out:
# math        67
# eng         57
# science     89
# arbi       100
# Name: rakib ar marks, dtype: int64

# %%
# attributes

# size


marks_series.size
# Out:
# 4

# %%
# dtype

marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'rakib ar marks'

# %%
# is_unique

marks_series.is_unique
# Out:
# True

# %%
# 
marks_series.index
# Out:
# Index(['math', 'eng', 'science', 'arbi'], dtype='object')

# %%
runs.index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
# values

marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %%
type(marks_series.values)
# Out:
# numpy.ndarray

# %%
#series using read_csv
pd.read_csv("C:/Users/RAHAT/Desktop/Pandas df_campus/subs.csv")
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
type(pd.read_csv("C:/Users/RAHAT/Desktop/Pandas df_campus/subs.csv"))
# Out:
# pandas.core.frame.DataFrame

# %%
s = pd.read_csv("C:/Users/RAHAT/Desktop/Pandas df_campus/subs.csv")
s = s.squeeze()

# %%
s
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#

vk=pd.read_csv("C:\\Users\RAHAT\\Desktop\\Pandas df_campus\kohli_ipl.csv",index_col='match_no')

vk
type(vk)


vk=vk.squeeze()
type(vk)
# Out:
# pandas.core.series.Series

# %%
d
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie=pd.read_csv("C:\\Users\RAHAT\\Desktop\\Pandas df_campus\\bollywood.csv",index_col='movie')

# %%
movie=movie.squeeze()
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object
